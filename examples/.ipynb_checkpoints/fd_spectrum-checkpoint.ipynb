# %%
"""
Name: fd_spectrum.ipynb
Authors: Stephan Meighen-Berger
Testing ground for different light emission spectra
"""
# Out:
# '\nName: fd_spectrum.ipynb\nAuthors: Stephan Meighen-Berger\nTesting ground for different light emission spectra\n'

# %%
"""
Imports
"""
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma
from scipy.signal import peak_widths, find_peaks
from scipy.optimize import root
import logging
import warnings
from scipy.stats import gamma
import sys
sys.path.append("../core/")

# %%
# Latex text rendering
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
# Importing dob module
from fourth_day import FD
from fd_config import config

# %%
# Setting the debug level
# logging.basicConfig(level=logging.DEBUG)
# Turning off warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
fd = FD(org_filter='generous')

# %%
std_size = 6.
fontsize = 20.
lw=3.

# %%
# Order of the populations
fd.keys
# Out:
# array(['Aulacoctena acuminata Mortensen', 'Bathocyroe fosteri Madin',
#        'Bathocyroe fosteri Harbison', 'Bathyctena chuni (Moser)',
#        'Bathyctena sp. nov. Aa', 'Bathyctena sp. nov. Ba',
#        'Bathyctenidae gen. nov. sp. nov.a', 'Beroe abyssicola Mortensen',
#        'Beroe cucumis Fabricius', 'Beroe forskalii Milne Edwards',
#        'Beroe gracilis KuÃˆnne', 'Beroe ovata Bosc',
#        'Bolinopsis infundibulum MuÃˆllerb',
#        'Bolinopsis vitrea (L. Agassiz)', 'Cestum veneris Lesueur',
#        'Charistephane fugiens Chun', 'Cydippida unidentified speciesa',
#        'Deiopea kaloktenota Chun', 'Euplokamis sp.',
#        'Euplokamis stationis Chun', 'Eurhamphaea vexilligera Gegenbaur',
#        'Haeckelia beehleri (Mayer)',
#        'Haeckelia bimaculata CarreÃ‚ and CarreÃ‚',
#        'Haeckelia rubra (KoÃˆlliker)',
#        'Kiyohimea aurita Komai and Tokioka', 'Lampea sp.',
#        'Lampea lactea (Mayer)', 'Lampea pancerina (Chun)',
#        'Leucothea multicornis (Quoy and Gaimard)',
#        'Leucothea pulchra (Matsumoto)', 'Lobata sp. nov. Aac',
#        'Lobata sp. nov. Ba', 'New family gen. nov. sp. nov. Aa',
#        'New family gen. nov. sp. nov. Ba',
#        'Mertensiidae gen. nov. A sp. nov. Aa',
#        'Mertensiidae gen. nov. A sp. nov. Ba',
#        'Mertensiidae gen. nov. B sp. nov. Ca',
#        'Mertensiidae gen. nov. B sp. nov. Dad',
#        'Ocyropsis maculata immaculata Harbison and Miller',
#        'Thalassocalyce inconstans Madin and Harbison',
#        'Thalassocalycidae gen. nov. sp. nov.a',
#        'Velamen parallelum (Fol)', 'Atolla parva Russell',
#        'Atolla vanhoeffeni Russell', 'Atolla wyvillei Haeckel',
#        'Coronatae unidentified speciese', 'Nausithoe globifera Broch',
#        'Nausithoe atlantica Broch', 'Paraphyllina ransoni Russell',
#        'Periphylla periphylla PeÃ‚ron and Lesueur',
#        'Periphyllopsis braueri Vanhoeffen',
#        'Phacellophora camtschatica Brandtb', 'Poralia sp.',
#        'Aegina citrea Eschscholtz', 'Aeginura grimaldii Maas',
#        'Aequorea forskalea PeÃ‚ron and Lesueur',
#        'Bythotiara depressa Naumov',
#        'Clytia (=Phialidium) hemisphaericum (L.)',
#        'Cunina globosa Eschscholtz', 'Euphysora valdiviae Vanhoeffen',
#        'Halicreas minimum Fewkes', 'Halicreidae unidentified speciese',
#        'Haliscera conica Vanhoeffen', 'Halitrephes maasi Bigelow',
#        'Halitrephes valdiviae H.B. Bigelow', 'Halopsis ocellata Agassiz',
#        'Mitrocoma cellularia (Agassiz)', 'Mitrocomella sp.', 'Obelia sp.',
#        'Octophialucium funerarium (Quoy and Gaimard)',
#        'Pandea conica (Quoy and Gaimard)', 'Pegantha laevis H.B. Bigelow',
#        'Solmissus albescens (Gegenbaur)', 'Solmissus incisa (Fewkes)',
#        'Solmissus marshalli Agassiz and Mayer',
#        'Solmundella bitentaculata (Quoy and Gaimard)',
#        'Abylopsis tetragona (Otto)',
#        'Chuniphyes multidentata Lens and van Riemsdijk',
#        'Craseoa lathetica Pugh and Harbison',
#        'Hippopodius hippopus (ForskaÃŠl)', 'Maresearsia praeclara Totton',
#        'Muggiaea sp.', 'Nectadamas diomedeae (Bigelow)',
#        'Nectopyramis natans (Bigelow)', 'Praya dubia (Quoy and Gaimard)',
#        'Prayidae unidentified speciese', 'Rosacea plicata sensu Bigelow',
#        'Vogtia glabra Bigelow', 'Vogtia serrata (Moser)',
#        'Agalma okeni Eschscholtz', 'Apolemia sp. 1', 'Apolemia sp. 2',
#        'Bargmannia sp.', 'Bargmannia sp. nov.a', 'Erenna sp. nov.',
#        'Frillagalma vityazi Daniel',
#        'Halistemma amphytridis (Lesueur and Petit)', 'Halistemma sp.',
#        'Halistemma sp. nov.a', 'Nanomia bijuga (delle Chiaje)',
#        'Nanomia cara Agassiz', 'Photobacterium phosphoreum ANT-2200'],
#       dtype='<U49')

# %%
# Weighting them
pdf_spl = fd.smith.fd_smithing(population=np.random.rand(len(fd.smith.keys), 1))

# %%
# Energy distributions
figure, ax = plt.subplots(figsize=(std_size, std_size * 6. / 8.))
for key in fd.keys:
    ax.plot(config['pdf_grid'], fd.pdfs[key])
ax.plot(config['pdf_grid'], pdf_spl(config['pdf_grid']), lw=lw, color='k')
ax.set_xlim(200., 750)
ax.set_ylim(0., 0.03)
ax.set_xscale('linear')
ax.set_yscale('linear')
ax.set_xlabel(r'$\lambda\;[\mathrm{nm}]$', fontsize=fontsize)
ax.set_ylabel(r'$PDF$', fontsize=fontsize)
ax.tick_params(axis = 'both', which = 'major', labelsize=fontsize, direction='in')
ax.tick_params(axis = 'both', which = 'minor', labelsize=fontsize, direction='in')
plt.grid(True)
plt.show()

# %%
# figure.savefig("C:\\Users\\steph\\Desktop\\Emission_Profiles.png",
#                bbox_inches='tight')
